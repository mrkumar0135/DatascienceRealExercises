# %%
import numpy as np
import pandas as pd
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 'Budapest_PaRis', 'Brussels_londOn'], 'FlightNumber': [10045, np.nan, 10065, np.nan, 10085], 'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]], 'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways.)', '12. Air France', '"Swiss Air"']})
for i in range(0, len(df)):
    if np.isnan(df['FlightNumber'] [i]):
        df['FlightNumber'] [i] = df['FlightNumber'][i-1]+10
    else:
        df['FlightNumber'] [i]
df['FlightNumber'] = df['FlightNumber'].astype(int)
df
# Out:
# C:\Users\Ratheesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#               Airline  FlightNumber           From_To  RecentDelays
# 0              KLM(!)         10045      LoNDon_paris      [23, 47]
# 1   <Air France> (12)         10055      MAdrid_miLAN            []
# 2  (British Airways.)         10065  londON_StockhOlm  [24, 43, 87]
# 3      12. Air France         10075    Budapest_PaRis          [13]
# 4         "Swiss Air"         10085   Brussels_londOn      [67, 32]

# %%
df['From'], df['To'] = df['From_To'].str.split('_', 1).str#.title()

# %%
df['From']=df['From'].str.title()
df['To']=df['To'].str.title()
df
# Out:
#               Airline  FlightNumber           From_To  RecentDelays      From  \
# 0              KLM(!)         10045      LoNDon_paris      [23, 47]    London
# 1   <Air France> (12)         10055      MAdrid_miLAN            []    Madrid
# 2  (British Airways.)         10065  londON_StockhOlm  [24, 43, 87]    London
# 3      12. Air France         10075    Budapest_PaRis          [13]  Budapest
# 4         "Swiss Air"         10085   Brussels_londOn      [67, 32]  Brussels
#
#           To
# 0      Paris
# 1      Milan
# 2  Stockholm
# 3      Paris
# 4     London

# %%
dfDelay =df['RecentDelays'].apply(lambda row: pd.Series(row))
dfDelay.columns = ['Delay 1', 'Delay 2', 'Delay 3']
dfDelay
# Out:
#    Delay 1  Delay 2  Delay 3
# 0     23.0     47.0      NaN
# 1      NaN      NaN      NaN
# 2     24.0     43.0     87.0
# 3     13.0      NaN      NaN
# 4     67.0     32.0      NaN

# %%
dfNew = df.join(dfDelay)
dfNew.drop('RecentDelays', axis=1, inplace=True)
dfNew
# Out:
#               Airline  FlightNumber           From_To      From         To  \
# 0              KLM(!)         10045      LoNDon_paris    London      Paris
# 1   <Air France> (12)         10055      MAdrid_miLAN    Madrid      Milan
# 2  (British Airways.)         10065  londON_StockhOlm    London  Stockholm
# 3      12. Air France         10075    Budapest_PaRis  Budapest      Paris
# 4         "Swiss Air"         10085   Brussels_londOn  Brussels     London
#
#    Delay 1  Delay 2  Delay 3
# 0     23.0     47.0      NaN
# 1      NaN      NaN      NaN
# 2     24.0     43.0     87.0
# 3     13.0      NaN      NaN
# 4     67.0     32.0      NaN
